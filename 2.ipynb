# %%
import tarfile
fileobject=tarfile.open('dataset.tar.gz','w')
fileobject.add('dataset')
fileobject.close()

# %%
from PIL import Image
import pillow_heif
for i in range(1,189):
    try:
        heif_file=pillow_heif.read_heif('dataset/untitled folder/Image'+str(i)+'.HEIC')
        image=Image.frombytes(heif_file.mode,heif_file.size,heif_file.data,"raw")
        image.save("dataset/1/Image"+str(i)+".jpeg",format("jpeg"))
    except:
        print("error")
        pass
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error

# %%
#Import required Image library
from PIL import Image
for i in range(1,467):
    im = Image.open("dataset/train/Pothole/Image"+str(i)+".jpg")
    #Make the new image half the width and half the height of the original image
    resized_im = im.resize((round(im.size[0]*0.5), round(im.size[1]*0.5)))
    im.convert('RGB')
    #Save the cropped image
    resized_im.save('dataset/'+str(i)+'.jpeg')
for i in range(468,1020):
    im = Image.open("dataset/train/Pothole/Image"+str(i)+".png")
    #Make the new image half the width and half the height of the original image
    resized_im = im.resize((round(im.size[0]*0.5), round(im.size[1]*0.5)))

    #Save the cropped image
    resized_im.save('dataset/3/.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     628     try:
# --> 629         rawmode = RAWMODE[im.mode]
#     630     except KeyError as e:
#
# KeyError: 'RGBA'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# /var/folders/13/f9l9g0c55rj89ch9b5tnbmrw0000gn/T/ipykernel_5407/953526035.py in <module>
#       7     im.convert('RGB')
#       8     #Save the cropped image
# ----> 9     resized_im.save('dataset/'+str(i)+'.jpeg')
#      10 for i in range(468,1020):
#      11     im = Image.open("dataset/train/Pothole/Image"+str(i)+".png")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2238
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#    2242             # do what we can to clean up
#
# ~/opt/anaconda3/lib/python3.9/site-packages/PIL/JpegImagePlugin.py in _save(im, fp, filename)
#     629         rawmode = RAWMODE[im.mode]
#     630     except KeyError as e:
# --> 631         raise OSError(f"cannot write mode {im.mode} as JPEG") from e
#     632
#     633     info = im.encoderinfo
#
# OSError: cannot write mode RGBA as JPEG
