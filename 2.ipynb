# %%
import tarfile
fileobject=tarfile.open('dataset.tar.gz','w')
fileobject.add('dataset')
fileobject.close()

# %%
from PIL import Image
import pillow_heif
for i in range(1,189):
    try:
        heif_file=pillow_heif.read_heif('dataset/untitled folder/Image'+str(i)+'.HEIC')
        image=Image.frombytes(heif_file.mode,heif_file.size,heif_file.data,"raw")
        image.save("dataset/1/Image"+str(i)+".jpeg",format("jpeg"))
    except:
        print("error")
        pass
# Out:
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# ...

# %%
#Import required Image library
from PIL import Image
for i in range(1,467):
    im = Image.open("dataset/train/Pothole/Image"+str(i)+".jpg")
    #Make the new image half the width and half the height of the original image
    resized_im = im.resize((round(im.size[0]*0.5), round(im.size[1]*0.5)))
    im.convert('RGB')
    #Save the cropped image
    resized_im.save('dataset/'+str(i)+'.jpeg')
for i in range(468,1020):
    im = Image.open("dataset/train/Pothole/Image"+str(i)+".png")
    #Make the new image half the width and half the height of the original image
    resized_im = im.resize((round(im.size[0]*0.5), round(im.size[1]*0.5)))

    #Save the cropped image
    resized_im.save('dataset/3/.png')
